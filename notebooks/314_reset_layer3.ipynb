# %% [markdown]
# # 314 — Reset Layer 3

# %% [markdown]
# Delete all CaseAssessment, RiskFinding, InvestigationStep nodes. Run to clean up between demos.

# %%
# Run 311 first
result = execute_tool("write-neo4j-cypher", {
    "query": "MATCH (n:CaseAssessment|RiskFinding|InvestigationStep) DETACH DELETE n"
})
print("Layer 3 cleared")
