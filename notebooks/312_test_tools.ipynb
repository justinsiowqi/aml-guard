# %% [markdown]
# # 312 — Test All MCP Tools

# %% [markdown]
# Smoke-test each tool in tool_defs.py against a live entity from Layer 1.

# %%
# Run 311 first
# TODO: replace ENT-0001 with a real entity_id once data is loaded
result = execute_tool("traverse_entity_network", {"entity_id": "ENT-0001", "entity_type": "Entity"})
print(result)

# %%
result = execute_tool("detect_graph_anomalies", {"pattern_names": ["transaction_structuring"]})
print(result)

# %%
result = execute_tool("retrieve_typology_chunks", {"query_text": "cash structuring below reporting threshold"})
print(result)
