# %% [markdown]
# # 211 — Extract Typology Structure from PDFs

# %% [markdown]
# Extract Section and Indicator nodes from FATF/AUSTRAC PDFs. Mirror of loanguard-ai notebook 211.

# %%
# TODO: mirror loanguard-ai/notebooks/211_extract_structure.ipynb
# Replace Regulation/Requirement/Threshold with Typology/Indicator
# document_config.yaml drives which PDFs to process
