# %% [markdown]
# # 214 — Embed Chunks and Build Vector Index

# %% [markdown]
# Embed chunks with OpenAI text-embedding-3-small and push to Neo4j vector index.

# %%
# TODO: mirror loanguard-ai/notebooks/214_embed_chunks.ipynb
# Index name: chunk_embeddings
# Dimensions: 1536
# Similarity: cosine
