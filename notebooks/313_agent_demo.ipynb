# %% [markdown]
# # 313 — AML Agent Demo

# %% [markdown]
# End-to-end demo of AMLAgent.run() against a live entity.

# %%
# Run 311 first
from src.agent.aml_agent import AMLAgent

agent = AMLAgent(execute_tool)
# TODO: replace with a real entity_id once Layer 1 is loaded
response = agent.run("Investigate entity ENT-0001 for AML risk.")
print(response.verdict, response.risk_score)
for f in response.findings:
    print(f)
