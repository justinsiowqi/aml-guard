# %% [markdown]
# # 212 — Merge Typologies into Neo4j

# %% [markdown]
# Load extracted CSV data from notebook 211 into Neo4j Layer 2.

# %%
# TODO: mirror loanguard-ai/notebooks/212_merge_graph.ipynb
